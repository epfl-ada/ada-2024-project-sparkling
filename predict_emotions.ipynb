# %%
from src.data.data_wrangling import load_and_clean_movies_df
from src.data.predict_emotions import *

# Make sure that if any dependencies changes it will be reflected in the notebook (From the ML course)
# %load_ext autoreload
# %autoreload 2
# Out:
# 2024-11-08 14:33:48.914136: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %%
df_movies = load_and_clean_movies_df()

# %%
predict_emotions_to_csv(df_movies.head(50),
                        column_to_predict='plot', 
                        csv_path='plot_emotions.csv')
# Out:
# /Users/matthiaswyss/anaconda3/lib/python3.11/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# Processing emotions: 100%|██████████████████████| 50/50 [00:20<00:00,  2.38it/s]
# /Users/matthiaswyss/Documents/EPFL/2024-25/MA1/CS-401 Applied data analysis/Projet/ada-2024-project-sparkling/src/data/predict_emotions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['emotion_predictions'] = emotion_predictions.apply(lambda x: json.dumps(x))

# %%
# Merging df_movies with plot_emotions.csv
df_movies_with_emotions = merge_df_movies_with_emotions_csv(df_movies, 
                                                            csv_path='plot_emotions.csv')

# %%
df_movies_with_emotions.head()
# Out:
#    wikipedia_ID freebase_ID                       name     revenue  runtime  \
# 0        975900   /m/03vyhn             Ghosts of Mars  14010832.0     98.0
# 1       9363483  /m/0285_cd           White Of The Eye         NaN    110.0
# 2        261236   /m/01mrr1          A Woman in Flames         NaN    106.0
# 3      18998739  /m/04jcqvw  The Sorcerer's Apprentice         NaN     86.0
# 4       6631279   /m/0gffwj                Little city         NaN     93.0
#
#    release_year  release_month  release_day  Burmese Language  Hungary  ...  \
# 0          2001              8           24             False    False  ...
# 1          1987           <NA>         <NA>             False    False  ...
# 2          1983           <NA>         <NA>             False    False  ...
# 3          2002           <NA>         <NA>             False    False  ...
# 4          1997              4            4             False    False  ...
#
# ...

# %%
df_reviews = pd.read_csv('IMDBReviews1.csv')

# %%
predict_emotions_to_csv(df_reviews.head(50),
                        column_to_predict='review_detail', 
                        csv_path='review_emotions.csv')
# Out:
# Processing emotions: 100%|██████████████████████| 50/50 [00:15<00:00,  3.30it/s]
# /Users/matthiaswyss/Documents/EPFL/2024-25/MA1/CS-401 Applied data analysis/Projet/ada-2024-project-sparkling/src/data/predict_emotions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['emotion_predictions'] = emotion_predictions.apply(lambda x: json.dumps(x))

# %%
# Merging df_movies with review_emotions.csv
df_reviews_with_emotions = merge_df_reviews_with_emotions_csv(df_movies, 
                                                              csv_path='review_emotions.csv')

# %%
df_reviews_with_emotions
# Out:
#     wikipedia_ID freebase_ID               name      revenue  runtime  \
# 0         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 1         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 2         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 3         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 4         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 5         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 6         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 7         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 8         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 9         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 10        975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 11        975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# ...

# %%
# Merging df_movies_with_emotions with review_emotions.csv
df_movies_reviews_with_emotions = merge_df_reviews_with_emotions_csv(df_movies_with_emotions, 
                                                              csv_path='review_emotions.csv')

# %%
df_movies_reviews_with_emotions
# Out:
#     wikipedia_ID freebase_ID               name      revenue  runtime  \
# 0         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 1         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 2         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 3         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 4         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 5         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 6         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 7         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 8         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 9         975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 10        975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# 11        975900   /m/03vyhn     Ghosts of Mars   14010832.0     98.0
# ...
