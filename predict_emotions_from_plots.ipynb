# %%
from src.data.data_wrangling import load_and_clean_movies_df
from src.data.emotions import predict_emotions_to_csv, merge_df_movies_with_emotions_csv

# Make sure that if any dependencies changes it will be reflected in the notebook (From the ML course)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_movies = load_and_clean_movies_df()

# %%
predict_emotions_to_csv(df_movies)
# Out:
# Processing emotions: 100%|██████████████| 42204/42204 [4:17:23<00:00,  2.73it/s]

# %%
df_movies_with_emotions = merge_df_movies_with_emotions_csv(df_movies)

# %%
df_movies_with_emotions
# Out:
#        wikipedia_ID freebase_ID  \
# 0            975900   /m/03vyhn
# 1           9363483  /m/0285_cd
# 2            261236   /m/01mrr1
# 3          18998739  /m/04jcqvw
# 4           6631279   /m/0gffwj
# ...             ...         ...
# 42199      23851782  /m/06_vb43
# 42200      35228177  /m/0j7hxnt
# 42201      34980460  /m/0g4pl34
# 42202        913762   /m/03pcrp
# 42203      12476867  /m/02w7zz8
#
#                                                     name     revenue  runtime  \
# 0                                         Ghosts of Mars  14010832.0     98.0
# 1                                       White Of The Eye         NaN    110.0
# 2                                      A Woman in Flames         NaN    106.0
# 3                              The Sorcerer's Apprentice         NaN     86.0
# 4                                            Little city         NaN     93.0
# ...                                                  ...         ...      ...
# 42199                                    The Ghost Train         NaN     82.0
# 42200                           Mermaids: The Body Found         NaN    120.0
# 42201                                            Knuckle         NaN     96.0
# 42202  The Super Dimension Fortress Macross II: Lover...         NaN    150.0
# 42203                                            Spliced         NaN     86.0
#
#        release_year  release_month  release_day  France  Teochew  ...  \
# 0              2001              8           24   False    False  ...
# 1              1987           <NA>         <NA>   False    False  ...
# 2              1983           <NA>         <NA>   False    False  ...
# 3              2002           <NA>         <NA>   False    False  ...
# 4              1997              4            4   False    False  ...
# ...             ...            ...          ...     ...      ...  ...
# 42199          1941              5            3   False    False  ...
# 42200          2011              3           19   False    False  ...
# 42201          2011              1           21   False    False  ...
# 42202          1992              5           21   False    False  ...
# 42203          2002           <NA>         <NA>   False    False  ...
#
#        Race movie  Softcore Porn  \
# 0           False          False
# 1           False          False
# 2           False          False
# 3           False          False
# 4           False          False
# ...           ...            ...
# 42199       False          False
# 42200       False          False
# 42201       False          False
# 42202       False          False
# 42203       False          False
#
#                                                     plot     anger   disgust  \
# 0      Set in the second half of the 22nd century, th...  0.124897  0.218596
# 1      A series of murders of rich young women throug...  0.189591  0.212926
# 2      Eva, an upper class housewife, becomes frustra...  0.223667  0.242072
# 3      Every hundred years, the evil Morgana  returns...  0.093134  0.059586
# 4      Adam, a San Francisco-based artist who works a...  0.028604  0.042206
# ...                                                  ...       ...       ...
# 42199  The film opens with a Great Western express sp...  0.117082  0.101603
# 42200  Two former National Oceanic Atmospheric Admini...  0.021019  0.280469
# 42201  This film follows 12 years in the lives of 3 I...  0.313380  0.014388
# 42202  The story takes place in the year 2092,The Sup...  0.046676  0.071530
# 42203  The movie is about a teenage girl who loves ho...  0.135248  0.055442
#
#            fear       joy   neutral   sadness  surprise
# 0      0.192109  0.027494  0.291312  0.108787  0.036804
# 1      0.106211  0.075280  0.298569  0.079271  0.038153
# 2      0.015905  0.074039  0.320158  0.067359  0.056799
# 3      0.075151  0.082081  0.507801  0.139009  0.043239
# 4      0.155106  0.110992  0.208594  0.439004  0.015494
# ...         ...       ...       ...       ...       ...
# 42199  0.198354  0.029757  0.349803  0.100146  0.103255
# 42200  0.057400  0.018043  0.443206  0.015898  0.163965
# 42201  0.020681  0.263675  0.340062  0.031669  0.016144
# 42202  0.059907  0.118773  0.604935  0.038095  0.060084
# 42203  0.305358  0.006623  0.224535  0.082770  0.190024
#
# [42204 rows x 733 columns]

# %% [markdown]
# ##
